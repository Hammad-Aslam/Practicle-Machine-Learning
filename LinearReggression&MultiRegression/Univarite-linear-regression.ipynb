# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0,2.0,3.0,4.0])
y_train = np.array([100.0, 200.0, 300.0, 400.0])
print(f'xtrain', x_train)
print(f'ytrain', y_train)
# Out:
# xtrain [1. 2. 3. 4.]
# ytrain [100. 200. 300. 400.]

# %%
print(f'{x_train.shape} returns the tuple of dimension.')
print(f'{x_train.shape[0]} is the lenth of array.')
# Out:
# (4,) returns the tuple of dimension.
# 4 is the lenth of array.

# %%
i = 3
x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(3), y^(3)) = (4.0, 400.0)

# %%
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title('House Predication model')
plt.xlabel('size in 1000 feets')
plt.ylabel('price in $1000')
plt.show()

# %%
w = 80
b = 50
print(f'W: {w}')
print(f'B: {b}')
# Out:
# W: 80
# B: 50

# %%
def compute_model_output(x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
tmp_f_wb = compute_model_output(
    x_train,
    w,
    b,
)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c="b", label="Our Prediction")

# Plot the data points
plt.scatter(x_train, y_train, marker="x", c="r", label="Actual Values")

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel("Price (in 1000s of dollars)")
# Set the x-axis label
plt.xlabel("Size (1000 sqft)")
plt.legend()
plt.show()

# %%
w = 200
b = 100
x_i = 34
cost_1200sqft = w * x_i + b

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $6900 thousand dollars
